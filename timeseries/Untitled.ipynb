# %%
install.packages("astsa")
.First <- function(){library(astsa)}
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %% [markdown]
# ## 1.1

# %%
plot(speech)
# Out:
# plot without title

# %%
  plot(jj, type="o", ylab="Quarterly Earnings per Share")
# Out:
# plot without title

# %%
  plot(globtemp, type="o", ylab="Global Temperature Deviations")
# Out:
# plot without title

# %%
library(TTR)
library(xts)
# Out:
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
djia = getYahooData("^DJI", start=20060420, end=20160420, freq="daily")
# Out:
# Warning message:
# “TTR::getYahooData is deprecated and will be removed in a future release.
# Please use quantmod::getSymbols instead.”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '/var/folders/gk/v33s628j72z6sj3jm6k91zk00000gn/T//Rtmp4CvToM/file689973cc0b4e'”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '/var/folders/gk/v33s628j72z6sj3jm6k91zk00000gn/T//Rtmp4CvToM/file689973cc0b4e'”

# %%
djiar = diff(log(djia$Close))[-1] # approximate returns

# %%
plot(djiar, main="DJIA Returns", type="n")
lines(djiar)
# Out:
# plot without title
# plot without title

# %%
par(mfrow = c(2,1))

# %%
plot(soi, ylab="", xlab="", main="Southern Oscillation Index")
# Out:
# Plot with title “Southern Oscillation Index”

# %%
plot(rec, ylab="", xlab="", main="Recruitment")
# Out:
# Plot with title “Recruitment”

# %% [markdown]
# # 1.2
